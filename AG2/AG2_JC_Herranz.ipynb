# %% [markdown]
# <a href="https://colab.research.google.com/github/jcherranz2/03MAIR-Algoritmos-de-optimizacion/blob/master/AG2/AG2_JC_Herranz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AG2
# JUAN CARLOS HERRANZ
# https://github.com/jcherranz2/03MAIR-Algoritmos-de-optimizacion/tree/master/AG2

# %%
import random
import math

N = 3000
LISTA_2D = [ (random.randrange(1,N*10), random.randrange(1,N*10))  for _ in range(N)]
print(LISTA_2D)
# Out:
# [(22899, 20435), (26261, 7913), (8312, 4597), (23760, 15631), (22988, 14015), (18684, 28130), (14335, 1178), (6445, 6757), (9209, 27754), (21809, 16168), (28032, 28762), (5582, 1776), (18525, 29920), (7584, 8592), (15868, 12417), (13701, 16386), (24658, 16985), (1331, 25057), (6447, 6909), (13137, 13932), (12367, 8923), (24842, 27061), (7402, 5449), (25906, 12084), (17483, 22420), (22100, 12650), (19486, 8442), (15237, 21526), (24320, 16424), (12235, 29310), (4557, 9131), (11292, 18779), (21754, 3209), (11740, 26118), (2097, 19979), (15739, 26016), (1934, 21735), (16871, 18386), (12914, 19805), (129, 8740), (17116, 11130), (11744, 1772), (10149, 7170), (26197, 2434), (4773, 24136), (26856, 8224), (27674, 14558), (11704, 7597), (20386, 13643), (3267, 5256), (19750, 22596), (19731, 22805), (20111, 20097), (1582, 13767), (940, 6818), (23377, 18205), (6652, 19263), (2802, 25155), (9597, 14575), (8308, 11227), (6014, 12921), (17979, 25506), (3045, 1081), (27499, 9453), (9291, 22045), (966
# ...

# %%
def distancia(A,B):
  if type(A) is int or type(A) is float:
    return abs(B-A)
  else:
    return math.sqrt(sum([(A[i]-B[i])**2 for i in range(len(A))]))
    
distancia((-2,3),(2,5))
# Out:
# 4.47213595499958

# %%
# DISTANCIA POR FUERZA BRUTA
def distancia_fuerza_bruta(L):
  mejor_distancia = 10000e10
  
  A,B = (), ()
  for i in range(len(L)):
     for j in range(i+1, len(L)):
        D = distancia(L[i], L[j])
        if D < mejor_distancia:
                 A, B = L[i], L[j]
                 mejor_distancia = D
  return [A,B]
# %timeit distancia_fuerza_bruta(LISTA_2D)
# Out:
# 1 loop, best of 3: 9.81 s per loop

# %%
# DOS PUNTOS MÁS CERCANOS CON  DIVIDE Y VENCERÁS

# %%
def distancia_divide_y_venceras(L):
    #Si hay pocos mejor por fuerza bruta
    if len(L) <=10:
      return distancia_fuerza_bruta(L)
  
    #Dividimos por la primera coordena
    pivote = sum([L[i][0] for i in range(len(L))])/len(L)
               
    LISTA_IZQ = sorted(L, key=lambda x: x[0])[:len(L)//2]
    LISTA_DER = sorted(L, key=lambda x: x[0])[ len(L)//2:]       

    #PUNTOS_LISTA_IZQ = distancia_divide_y_venceras(LISTA_IZQ)
    #PUNTOS_LISTA_DER = distancia_divide_y_venceras(LISTA_DER)      
    
    
    return distancia_fuerza_bruta(distancia_divide_y_venceras(LISTA_IZQ)+distancia_divide_y_venceras(LISTA_DER))

# %%
# PREFIERO USAR TIMEIT PARA MEDIR TIEMPOS
# %timeit distancia_divide_y_venceras(LISTA_2D)
# Out:
# 10 loops, best of 3: 40.4 ms per loop

# %%
distancia_divide_y_venceras(LISTA_2D)

# %%
# PROGRAMACIÓN DINÁMICA PASEO POR EL RIO
TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]

def Precios(TARIFAS):
  N = len(TARIFAS[0])
  
  PRECIOS = [ [9999]*N for i in [9999]*N]
  RUTA = [ [""]*N for i in [""]*N]
  
  for i in range(N-1):
    for j in range(i+1,N):
      MIN = TARIFAS[i][j]
      RUTA[i][j] = i
      
      for k in range(i,j):
        if PRECIOS[i][k] + TARIFAS[k][j] < MIN:
          MIN = min(MIN, PRECIOS[i][k]+TARIFAS[k][j])
          RUTA[i][j] = k
          
      PRECIOS[i][j] = MIN
    return PRECIOS, RUTA

# %%
PRECIOS, RUTAS = Precios(TARIFAS)
print(PRECIOS)
print()
print(RUTAS)

def calcular_ruta(RUTAS, desde, hasta):
  if desde == hasta:
    return desde
  else:
    return str(calcular_ruta(RUTAS, desde, RUTAS[desde][hasta])) + ',' +str(RUTAS[desde][hasta])
print("\nLa ruta es:")
calcular_ruta(RUTAS, 0,6)
# Out:
# [[9999, 5, 4, 3, 8, 8, 11], [9999, 9999, 9999, 9999, 9999, 9999, 9999], [9999, 9999, 9999, 9999, 9999, 9999, 9999], [9999, 9999, 9999, 9999, 9999, 9999, 9999], [9999, 9999, 9999, 9999, 9999, 9999, 9999], [9999, 9999, 9999, 9999, 9999, 9999, 9999], [9999, 9999, 9999, 9999, 9999, 9999, 9999]]
#
# [['', 0, 0, 0, 1, 2, 5], ['', '', '', '', '', '', ''], ['', '', '', '', '', '', ''], ['', '', '', '', '', '', ''], ['', '', '', '', '', '', ''], ['', '', '', '', '', '', ''], ['', '', '', '', '', '', '']]
#
# La ruta es:
# '0,0,2,5'
